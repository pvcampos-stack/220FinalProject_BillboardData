# %% [markdown]
# ## References
# 1. [https://medium.com/@Doug-Creates/reorder-dataframe-columns-in-pandas-b4b2823be20e](Reorder DataFrame Columns in Pandas)
# 2. [https://pandas.pydata.org/docs/reference/api/pandas.Series.to_frame.html](pandas.Series.to_frame)
# 3. [https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.rename.html](pandas.DataFrame.rename)
# 4. [https://dev.to/atifwattoo/explanation-of-the-syntax-dfcolumn-expression-in-pandas-539d](Explanation of the syntax \`df\[\'column\'\] = expression\` in pandas)
# 5. [https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.to_sql.html](pandas.DataFrame.to_sql)
# 6. [https://docs.python.org/3/library/datetime.html](datetime — Basic date and time types)
# 7. [https://stackoverflow.com/questions/9504356/convert-string-into-date-type-on-python](Convert string into Date type on Python \[duplicate\])
# 8. [https://www.geeksforgeeks.org/pandas/check-for-a-substring-in-a-pandas-dataframe-column/](Check For A Substring In A Pandas Dataframe Column)
# 9. [https://stackoverflow.com/questions/6797984/how-do-i-lowercase-a-string-in-python](How do I lowercase a string in Python?)
# 10. [https://www.geeksforgeeks.org/python/get-unique-values-from-a-column-in-pandas-dataframe/](Get Unique Values from a Column in Pandas DataFrame)
# 11. [https://www.geeksforgeeks.org/pandas/python-pandas-dataframe-sum/](Pandas dataframe.sum()
# )
# 12. [https://stackoverflow.com/questions/22245171/how-to-lowercase-a-pandas-dataframe-string-column-if-it-has-missing-values](How to lowercase a pandas dataframe string column if it has missing values?)
# 13. [https://stackoverflow.com/questions/58478230/how-to-return-match-with-a-string-that-contains-parentheses-in-pandas](How to return match with a string that contains parentheses in pandas?)
# 14. [https://stackoverflow.com/questions/60473593/python-requests-raise-for-status-exceptions-find-the-output](Python requests.raise_for_status() exceptions find the output)
# 15. [https://www.geeksforgeeks.org/python/get-current-date-and-time-using-python/](How to Get Current Date and Time using Python)
