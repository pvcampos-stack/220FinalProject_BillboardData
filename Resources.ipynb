# %% [markdown]
# ## References
# 1. [Reorder DataFrame Columns in Pandas](https://medium.com/@Doug-Creates/reorder-dataframe-columns-in-pandas-b4b2823be20e)
# 2. [pandas.Series.to_frame](https://pandas.pydata.org/docs/reference/api/pandas.Series.to_frame.html)
# 3. [pandas.DataFrame.rename](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.rename.html)
# 4. [Explanation of the syntax \`df\[\'column\'\] = expression\` in pandas](https://dev.to/atifwattoo/explanation-of-the-syntax-dfcolumn-expression-in-pandas-539d)
# 5. [pandas.DataFrame.to_sql](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.to_sql.html)
# 6. [datetime — Basic date and time types](https://docs.python.org/3/library/datetime.html)
# 7. [Convert string into Date type on Python \[duplicate\]](https://stackoverflow.com/questions/9504356/convert-string-into-date-type-on-python)
# 8. [Check For A Substring In A Pandas Dataframe Column](https://www.geeksforgeeks.org/pandas/check-for-a-substring-in-a-pandas-dataframe-column/)
# 9. [How do I lowercase a string in Python?](https://stackoverflow.com/questions/6797984/how-do-i-lowercase-a-string-in-python)
# 10. [Get Unique Values from a Column in Pandas DataFrame](https://www.geeksforgeeks.org/python/get-unique-values-from-a-column-in-pandas-dataframe/)
# 11. [Pandas dataframe.sum()](https://www.geeksforgeeks.org/pandas/python-pandas-dataframe-sum/)
# 12. [How to lowercase a pandas dataframe string column if it has missing values?](https://stackoverflow.com/questions/22245171/how-to-lowercase-a-pandas-dataframe-string-column-if-it-has-missing-values)
# 13. [How to return match with a string that contains parentheses in pandas?](https://stackoverflow.com/questions/58478230/how-to-return-match-with-a-string-that-contains-parentheses-in-pandas)
# 14. [Python requests.raise_for_status() exceptions find the output](https://stackoverflow.com/questions/60473593/python-requests-raise-for-status-exceptions-find-the-output)
# 15. [How to Get Current Date and Time using Python](https://www.geeksforgeeks.org/python/get-current-date-and-time-using-python/)
# 16. [Deep Copy and Shallow Copy in Python](https://www.geeksforgeeks.org/python/copy-python-deep-copy-shallow-copy/)
# 17. [pandas.DataFrame.to_csv](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.to_csv.html)
# 18. [How to check for NaN values](https://stackoverflow.com/questions/944700/how-to-check-for-nan-values)
# 19. [Delete Records from SQL Table using query in pandas](https://stackoverflow.com/questions/63660150/delete-records-from-sql-table-using-query-in-pandas#:~:text=from%20sqlalchemy%20import%20create_engine%20engine,Gini%20Engg%204%20Bist%20Lawyer)
# 20. [pandas.DataFrame.to_sql](https://pandas.pydata.org/pandas-docs/version/0.22/generated/pandas.DataFrame.to_sql.html)
